# %% [markdown]
# # Théorie des jeux - classes
#
# pour une intoduction, et un aperçu de ce que l'on va faire, voir [ncase](https://ncase.me/trust/)
# (ce sera plus simple)
#
# On joue à un jeu à 2 joueurs, défini ainsi:
#
# ![image.png](attachment:image.png)
#
#
# Pour ca on va définir une classe joueur et la faire jouer

# %% [markdown]
# 1. créer un classe $Joueur$ avec un nom, et une constante $STRATEGIE="enthousiaste"$
# 2. à l'initialisation on crée aussi une $memoire$ (liste vide) et un $pecule$ initialisé à 100.
# 3. créer une méthode $\_\_str\_\_$ qui renvoie une description (nom et stratégie)
# 4. tester avec une joueuse "Marie"

# %%
class Joueur:
    STRATEGIE = "enthousiaste"
    
    def __init__(self,nom,pecule=100):
        self.nom = nom
        self.memoire = []
        self.pecule = pecule
        
    def __str__(self):
        pass
    
    def cooperate(self):
        pass
    
    def start(self):
        pass
    
    def jouer_une_fois(self,autre):
        pass
    
    def jouer(self,autre):
        pass
    
    def resultat(self,autre):
        """Affiche les résultat du jeu avec autre"""
        pass

# %% [markdown]
# #### Sur la même classe
# 5. ajouter une méthode $cooperate$ qui renvoie toujours vrai
# 6. ajouter une méthode $start$ qui initialise le pécule à 100 et la mémoire vide

# %% [markdown]
# 7. ajouter une méthode $jouer\_une\_fois$ qui prend un autre joueur et fait une étape du jeu:
#   - elle appelle les méthodes $cooperate$ de chaque joueur
#   - en fonction des résultats, elle attribue les gains
#   - elle note dans la mémoire de chaque joueur un _tuple_ contenant ce qu'il a joué et ce que l'autre a joué

# %% [markdown]
# 8. Créer une classe $Tricheur$ qui hérite de $Joueur$ et modifier la méthode $cooperate$ pour renvoyer toujours $False$
# 9. Créer un _Tricheur_ qui s'appelle "Jacques"
# 10. Faire jouer Marie contre Jacques et regarder les gains 1 fois

# %% [markdown]
# 11. Ajouter une méthode $jouer$ qui appelle $start$, puis $jouer\_une\_fois$ un nombre donné de fois ($n$)
# 12. Créer une classe $Copieur$ qui hérite de $Joueur$ et modifier la méthode $cooperate$ pour renvoyer d'abord $True$ puis copie la valeur donnée par l'autre la dernière fois.
# 13. Créer une classe $Entete$ qui hérite de $Joueur$ et modifier la méthode $cooperate$ pour renvoyer d'abord $True$ puis donne toujours $True$ ou $False$ en fonction de ce que l'autre a joué la première fois.
# 14. Ajouter une copieuse, "Laure", et un entêté, "Patrick"
# 15. Faire jouer Laure contre Jacques 10 fois et voir le résultat

# %% [markdown]
# 16. Faire jouer chacun des joueur 5 fois contre un autre et noter les résultats dans un tableau. Qui gagne?

# %% [markdown]
# 17. inventer une nouvelle stratégie et l'implémenter
